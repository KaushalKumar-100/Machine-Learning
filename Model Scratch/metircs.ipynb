# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("placement (1).csv")

# %%
random=np.random.random(200)
new_df=df.copy()
new_df["random"]=random
new_df.head()
# Out:
#    cgpa  package    random
# 0  6.89     3.26  0.230894
# 1  5.12     1.98  0.885583
# 2  7.82     3.25  0.129822
# 3  7.42     3.67  0.345037
# 4  6.94     3.57  0.363719

# %%
df=new_df.copy()

# %%
df.head()
# Out:
#    cgpa  package    random
# 0  6.89     3.26  0.230894
# 1  5.12     1.98  0.885583
# 2  7.82     3.25  0.129822
# 3  7.42     3.67  0.345037
# 4  6.94     3.57  0.363719

# %%
plt.scatter(df["cgpa"],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel("CGPA")
plt.ylabel("package In lpa")
# Out:
# Text(0, 0.5, 'package In lpa')

# %%
x=df.iloc[:,0].values
y=df.iloc[:,1].values

# %%
x
# Out:
# array([6.89, 5.12, 7.82, 7.42, 6.94, 7.89, 6.73, 6.75, 6.09, 8.31, 5.32,
#        6.61, 8.94, 6.93, 7.73, 7.25, 6.84, 5.38, 6.94, 7.48, 7.28, 6.85,
#        6.14, 6.19, 6.53, 7.28, 8.31, 5.42, 5.94, 7.15, 7.36, 8.1 , 6.96,
#        6.35, 7.34, 6.87, 5.99, 5.9 , 8.62, 7.43, 9.38, 6.89, 5.95, 7.66,
#        5.09, 7.87, 6.07, 5.84, 8.63, 8.87, 9.58, 9.26, 8.37, 6.47, 6.86,
#        8.2 , 5.84, 6.6 , 6.92, 7.56, 5.61, 5.48, 6.34, 9.16, 7.36, 7.6 ,
#        5.11, 6.51, 7.56, 7.3 , 5.79, 7.47, 7.78, 8.44, 6.85, 6.97, 6.94,
#        8.99, 6.59, 7.18, 7.63, 6.1 , 5.58, 8.44, 4.26, 4.79, 7.61, 8.09,
#        4.73, 6.42, 7.11, 6.22, 7.9 , 6.79, 5.83, 6.63, 7.11, 5.98, 7.69,
#        6.61, 7.95, 6.71, 5.13, 7.05, 7.62, 6.66, 6.13, 6.33, 7.76, 7.77,
#        8.18, 5.42, 8.58, 6.94, 5.84, 8.35, 9.04, 7.12, 7.4 , 7.39, 5.23,
#        6.5 , 5.12, 5.1 , 6.06, 7.33, 5.91, 6.78, 7.93, 7.29, 6.68, 6.37,
#        5.84, 6.05, 7.2 , 6.1 , 5.64, 7.14, 7.91, 7.19, 7.91, 6.76, 6.93,
# ...

# %%
y_train.shape
# Out:
# (160, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
y_train=pd.DataFrame(y_train,columns=['placement'])
X_train=pd.DataFrame(X_train,columns=['cgpa'])
X_test=pd.DataFrame(X_test,columns=['cgpa'])

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import(
    mean_absolute_error,
    mean_squared_error,
    r2_score)

# %%
y_pred=lr.predict(X_test)

# %%
print("mean_absoulte errre",mean_absolute_error(y_test,y_pred))
# Out:
# mean_absoulte errre 0.2884710931878175

# %%
print("mean_squared_error",mean_squared_error(y_test,y_pred))
# Out:
# mean_squared_error 0.12129235313495527

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.34827051717731616

# %%
print("R2 score",r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# R2 score 0.780730147510384

# %%
X_test.shape
# Out:
# (40, 1)

# %%
num=(1-r2)*(40-1)
den=38
ans=1-num/den

# %%
ans
# Out:
# 0.7749598882343415

# %%
random=np.random.random(200)
new_df=df.copy()
new_df["random"]=random
new_df.head()
# Out:
#    cgpa  package    random
# 0  6.89     3.26  0.977179
# 1  5.12     1.98  0.950617
# 2  7.82     3.25  0.605315
# 3  7.42     3.67  0.890235
# 4  6.94     3.57  0.596478

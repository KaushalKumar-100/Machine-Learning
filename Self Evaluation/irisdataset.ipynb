# %%
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# %pip install --exists-action=i scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\kaush\desktop\summerbreak\machine learning\machinelearning\.venv-1\lib\site-packages (from scikit-learn) (2.4.6)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.2 MB 3.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.2 MB 2.3 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.2 MB 2.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.2 MB 2.4 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.2 MB 2.5 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.2 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.7/8.2 MB 2.5 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.2 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.2 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.2 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.2 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 2.5 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/36.5 MB 2.5 MB/s eta 0:00:15
#     --------------------------------------- 0.8/36.5 MB 2.0 MB/s eta 0:00:19
#    - -------------------------------------- 1.6/36.5 MB 2.3 MB/s eta 0:00:16
#    -- ------------------------------------- 2.1/36.5 MB 2.3 MB/s eta 0:00:15
#    -- ------------------------------------- 2.6/36.5 MB 2.4 MB/s eta 0:00:15
#    --- ------------------------------------ 3.1/36.5 MB 2.4 MB/s eta 0:00:14
#    ---- ----------------------------------- 3.7/36.5 MB 2.5 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.2/36.5 MB 2.5 MB/s eta 0:00:14
#    ----- ---------------------------------- 4.7/36.5 MB 2.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.2/36.5 MB 2.5 MB/s eta 0:00:13
#    ------ --------------------------------- 5.8/36.5 MB 2.5 MB/s eta 0:00:13
#    ------ --------------------------------- 6.3/36.5 MB 2.5 MB/s eta 0:00:13
#    ------- -------------------------------- 6.8/36.5 MB 2.5 MB/s eta 0:00:13
#    -------- ------------------------------- 7.3/36.5 MB 2.5 MB/s eta 0:00:12
#    -------- ------------------------------- 7.9/36.5 MB 2.5 MB/s eta 0:00:12
#    --------- ------------------------------ 8.4/36.5 MB 2.5 MB/s eta 0:00:12
#    ---------- ----------------------------- 9.2/36.5 MB 2.5 MB/s eta 0:00:11
#    ---------- ----------------------------- 9.7/36.5 MB 2.5 MB/s eta 0:00:11
#    ----------- ---------------------------- 10.2/36.5 MB 2.5 MB/s eta 0:00:11
#    ----------- ---------------------------- 10.7/36.5 MB 2.5 MB/s eta 0:00:11
#    ------------ --------------------------- 11.3/36.5 MB 2.5 MB/s eta 0:00:11
#    ------------ --------------------------- 11.8/36.5 MB 2.5 MB/s eta 0:00:10
#    ------------- -------------------------- 12.3/36.5 MB 2.5 MB/s eta 0:00:10
#    -------------- ------------------------- 12.8/36.5 MB 2.5 MB/s eta 0:00:10
#    -------------- ------------------------- 13.4/36.5 MB 2.5 MB/s eta 0:00:10
#    --------------- ------------------------ 13.9/36.5 MB 2.5 MB/s eta 0:00:10
#    --------------- ------------------------ 14.4/36.5 MB 2.5 MB/s eta 0:00:09
#    ---------------- ----------------------- 14.9/36.5 MB 2.5 MB/s eta 0:00:09
#    ---------------- ----------------------- 15.5/36.5 MB 2.5 MB/s eta 0:00:09
#    ----------------- ---------------------- 16.0/36.5 MB 2.5 MB/s eta 0:00:09
#    ------------------ --------------------- 16.8/36.5 MB 2.5 MB/s eta 0:00:08
#    ------------------ --------------------- 17.3/36.5 MB 2.5 MB/s eta 0:00:08
#    ------------------- -------------------- 17.8/36.5 MB 2.5 MB/s eta 0:00:08
#    -------------------- ------------------- 18.4/36.5 MB 2.5 MB/s eta 0:00:08
#    -------------------- ------------------- 18.9/36.5 MB 2.5 MB/s eta 0:00:08
#    --------------------- ------------------ 19.4/36.5 MB 2.5 MB/s eta 0:00:07
#    --------------------- ------------------ 19.9/36.5 MB 2.5 MB/s eta 0:00:07
#    ---------------------- ----------------- 20.4/36.5 MB 2.5 MB/s eta 0:00:07
#    ---------------------- ----------------- 20.7/36.5 MB 2.5 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.0/36.5 MB 2.5 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.2/36.5 MB 2.4 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.2/36.5 MB 2.4 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.2/36.5 MB 2.4 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.5/36.5 MB 2.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.8/36.5 MB 2.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.8/36.5 MB 2.2 MB/s eta 0:00:07
#    ------------------------ --------------- 22.0/36.5 MB 2.2 MB/s eta 0:00:07
#    ------------------------ --------------- 22.0/36.5 MB 2.2 MB/s eta 0:00:07
#    ------------------------ --------------- 22.3/36.5 MB 2.1 MB/s eta 0:00:07
#    ------------------------ --------------- 22.3/36.5 MB 2.1 MB/s eta 0:00:07
#    ------------------------ --------------- 22.5/36.5 MB 2.1 MB/s eta 0:00:07
#    ------------------------ --------------- 22.5/36.5 MB 2.1 MB/s eta 0:00:07
#    ------------------------ --------------- 22.8/36.5 MB 2.0 MB/s eta 0:00:07
#    ------------------------- -------------- 23.1/36.5 MB 2.0 MB/s eta 0:00:07
#    ------------------------- -------------- 23.3/36.5 MB 2.0 MB/s eta 0:00:07
#    ------------------------- -------------- 23.3/36.5 MB 2.0 MB/s eta 0:00:07
#    ------------------------- -------------- 23.6/36.5 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 23.9/36.5 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 23.9/36.5 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 24.1/36.5 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 24.1/36.5 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 24.1/36.5 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 24.4/36.5 MB 1.8 MB/s eta 0:00:07
#    -------------------------- ------------- 24.6/36.5 MB 1.8 MB/s eta 0:00:07
#    --------------------------- ------------ 24.9/36.5 MB 1.8 MB/s eta 0:00:07
#    --------------------------- ------------ 25.2/36.5 MB 1.8 MB/s eta 0:00:07
#    --------------------------- ------------ 25.4/36.5 MB 1.8 MB/s eta 0:00:07
#    ---------------------------- ----------- 26.0/36.5 MB 1.8 MB/s eta 0:00:06
#    ---------------------------- ----------- 26.2/36.5 MB 1.8 MB/s eta 0:00:06
#    ----------------------------- ---------- 26.7/36.5 MB 1.8 MB/s eta 0:00:06
#    ----------------------------- ---------- 27.3/36.5 MB 1.8 MB/s eta 0:00:06
#    ------------------------------ --------- 27.8/36.5 MB 1.8 MB/s eta 0:00:05
#    ------------------------------- -------- 28.3/36.5 MB 1.8 MB/s eta 0:00:05
#    ------------------------------- -------- 28.8/36.5 MB 1.8 MB/s eta 0:00:05
#    -------------------------------- ------- 29.4/36.5 MB 1.8 MB/s eta 0:00:04
#    -------------------------------- ------- 29.9/36.5 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 30.4/36.5 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 30.9/36.5 MB 1.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 31.7/36.5 MB 1.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.2/36.5 MB 1.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.8/36.5 MB 1.9 MB/s eta 0:00:03
#    ------------------------------------ --- 33.3/36.5 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------- -- 33.8/36.5 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------- -- 34.3/36.5 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------- -- 34.6/36.5 MB 1.9 MB/s eta 0:00:02
#    -------------------------------------- - 35.1/36.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  35.7/36.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 1.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, joblib, scikit-learn
# Successfully installed joblib-1.5.3 narwhals-2.22.1 scikit-learn-1.9.0 scipy-1.17.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
print("Numpy:",np.__version__,
      "Pandas",pd.__version__,
      "seaborn",sns.__version__)
# Out:
# Numpy: 2.4.6 Pandas 3.0.3 seaborn 0.13.2

# %%
iris=load_iris(as_frame=True)  
print(type(iris))
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
df=iris.frame

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='str')

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
target_names=dict(
    enumerate(iris.target_names)
)

# %%
print(target_names)
# Out:
# {0: np.str_('setosa'), 1: np.str_('versicolor'), 2: np.str_('virginica')}

# %%
df["species"]=df["target"].map(target_names)

# %%
df.info()
df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
#  5   species            150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB
# (150, 6)

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
feature_cols=iris.feature_names
x=df[feature_cols]
y=df["target"]

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.DataFrame'>
# <class 'pandas.Series'>

# %%
x=x.to_numpy()
y=y.to_numpy()

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# species              0
# dtype: int64

# %%
feature_cols
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df["species"]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: str

# %%
sns.set_style("whitegrid")
sns.pairplot(df[feature_cols+["species"]],diag_kind="kde",hue="species")
plt.suptitle("Graph of all flowers")
# Out:
# Text(0.5, 0.98, 'Graph of all flowers')

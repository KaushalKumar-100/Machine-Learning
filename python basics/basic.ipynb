# %%
print("Enter your Name")
name=input("type Here")
# Out:
# Enter your Name

# %% [markdown]
# Reading a file

# %%
with open("input.txt",'r') as file:
    content=file.read()
print(content)
# Out:
# hellow this is just learning of file handlilng

# %% [markdown]
# Writing a file

# %%
with open("output.txt","w") as file1:
    file1.write("THis is just demo of writing a file from code")

# %% [markdown]
# adding new content to existing file

# %%
with open("output.txt","a") as file:
    file.write("\ntrying adding new content to file")

# %%
with open("output.txt","a")as file:
    file.write("something extra")

# %% [markdown]
# Error Handling

# %%
a=int(input("Enter a number"))
print(a)
# Out:
# 4

# %%
try:
 num=int(input("Enter a number"))
    print(num)
except ValueError:
    print("oops! this is not a valid")
# Out:
# oops! this is not a valid number

# %%
try:
    num=int(input("Enter a number:"))
    num2=100/num
    print(num2)
except Exception as e:
    print("recheck it",str(e))
# Out:
# recheck it division by zero

# %%
try:
    num=int(input("Enter a number:"))
    num2=100/num
    print(num2)
except ValueError:
    print("enter a valid number:")
except ZeroDivisionError:
    print("don't use 0 as divisor")
# Out:
# don't use 0 as divisor
